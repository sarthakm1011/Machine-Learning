# %%
# PROBLEM STATEMENT 1
# IP camera app download on mobile device
# Use the github code to  connect and make server and apply algorithm developed by Sir
# Works for Android Device
import urllib 
import cv2 
import numpy as np 
import time 
import matplotlib.pyplot as plt

class Recognizer:
    
    def __init__(self, url=""):
        self.url = url
        self.area_threshold = 400
        self.contour_size_threshold = 100
        
    def get_frame(self):
        img_response = urllib.urlopen(self.url)
        img_numpy = np.array(bytearray(img_response.read()), dtype=np.uint8)
        img = cv2.imdecode(img_numpy, -1)
#         print img
#         return img
    
    def pre_process(self, img):
        # apply Gauusian blur because numerically it gives better results
        im = cv2.GaussianBlur(img,(5,5),10)
#         plt.imshow(im)
        #cv2.imshow('Fake Image',im)
        gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        #print gray
        
        #apply image threshold
        th = 255 - cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)
        #print th
        
        kernel = np.ones((3,3)) / 9.0
        
        # morphological operations on the image for better procesing 
        processed = cv2.dilate(th,kernel, iterations=1)
        processed = cv2.erode(processed,kernel, iterations=1)
        processed = cv2.morphologyEx(processed, cv2.MORPH_OPEN, kernel)
        processed = cv2.morphologyEx(processed, cv2.MORPH_CLOSE, kernel)
        #print processed
        #print cv2.imshow('A', processed)
            
        # Find contours in image and sort on the basis of size 
        cnts,_ = cv2.findContours(processed, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        #print im
        contour = np.array([[[0,0]], [[10,0]], [[10,10]], [[5,4]]])
        area = cv2.contourArea(contour)
#         print area
#         print cnts[0][0]
#         print cv2.contourArea(cnts[0])
        #cnts = sorted(cnts, key=lambda x: cv2.contourArea(x))
        
        for cnt in cnts:
            if cv2.contourArea(cnt) > self.area_threshold:
                x,y,w,h = cv2.boundingRect(cnt)
                if np.abs(w-h) < self.contour_size_threshold:
                    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        return img
    
    def run(self):
        while True:
            #Get Frame
            fr = self.get_frame()
            
            #Get processed image
            pr_fr = self.pre_process(fr)
            
            #Display Img
            cv2.imshow('Digits', pr_fr)
            
            #IPHONE TAKE STREAM IMAGES FROM API CONTINIOUSLY CREATE
#             bytes+=self.stream.raw.read(1024)
#                 a = bytes.find('\xff\xd8')
#                 b = bytes.find('\xff\xd9')
#                 if a!=-1 and b!=-1:
#                     jpg = bytes[a:b+2]
#                     bytes= bytes[b+2:]
#                     img = cv2.imdecode(np.fromstring(jpg, dtype=np.uint8),cv2.IMREAD_COLOR)
        
            
            if cv2.waitKey(1) == ord('q'):
                break

                
                
if __name__ == '__main__':
    pass
    #Replace the URL with IP webcam shot.jpg IP:port
    #url = 'http://10.208.19.80:8081/shot.jpg'
    url = 'http://172.20.10.5:8080/shot.jpg'
    rec = Recognizer(url=url)
    rec.run()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-17340e3b7b55> in <module>()
#      94     url = 'http://172.20.10.5:8080/shot.jpg'
#      95     rec = Recognizer(url=url)
# ---> 96     rec.run()
#
# <ipython-input-1-17340e3b7b55> in run(self)
#      65         while True:
#      66             #Get Frame
# ---> 67             fr = self.get_frame()
#      68
#      69             #Get processed image
#
# <ipython-input-1-17340e3b7b55> in get_frame(self)
#      17
#      18     def get_frame(self):
# ---> 19         img_response = urllib.urlopen(self.url)
#      20         img_numpy = np.array(bytearray(img_response.read()), dtype=np.uint8)
#      21         img = cv2.imdecode(img_numpy, -1)
#
# /usr/lib/python2.7/urllib.pyc in urlopen(url, data, proxies, context)
#      85         opener = _urlopener
#      86     if data is None:
# ---> 87         return opener.open(url)
#      88     else:
#      89         return opener.open(url, data)
#
# /usr/lib/python2.7/urllib.pyc in open(self, fullurl, data)
#     211         try:
#     212             if data is None:
# --> 213                 return getattr(self, name)(url)
#     214             else:
#     215                 return getattr(self, name)(url, data)
#
# /usr/lib/python2.7/urllib.pyc in open_http(self, url, data)
#     348         if realhost: h.putheader('Host', realhost)
#     349         for args in self.addheaders: h.putheader(*args)
# --> 350         h.endheaders(data)
#     351         errcode, errmsg, headers = h.getreply()
#     352         fp = h.getfile()
#
# /usr/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#    1051         else:
#    1052             raise CannotSendHeader()
# -> 1053         self._send_output(message_body)
#    1054
#    1055     def request(self, method, url, body=None, headers={}):
#
# /usr/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     895             msg += message_body
#     896             message_body = None
# --> 897         self.send(msg)
#     898         if message_body is not None:
#     899             #message_body was not a string (i.e. it is a file) and
#
# /usr/lib/python2.7/httplib.pyc in send(self, data)
#     857         if self.sock is None:
#     858             if self.auto_open:
# --> 859                 self.connect()
#     860             else:
#     861                 raise NotConnected()
#
# /usr/lib/python2.7/httplib.pyc in connect(self)
#     834         """Connect to the host and port specified in __init__."""
#     835         self.sock = self._create_connection((self.host,self.port),
# --> 836                                            self.timeout, self.source_address)
#     837
#     838         if self._tunnel_host:
#
# /usr/lib/python2.7/socket.pyc in create_connection(address, timeout, source_address)
#     573
#     574     if err is not None:
# --> 575         raise err
#     576     else:
#     577         raise error("getaddrinfo returns an empty list")
#
# IOError: [Errno socket error] [Errno 111] Connection refused

# %%
# SudoKu Game computer Vision Completion. Augumented Reality 
# IDEA: Given an Equation on White Board. Put Camera on it and Equation Solved. 
# https://github.com/Sanahm/SudoCAM-Ku

# %%
# Finger Gesture Detection to play Mario 
# Table Tennis Ball in or out in  a professional Match
