# %%
# Problem to buy a house
# Scatter plots are not good when there is lot of noise. The data deviates from in
# Exportation ie some random way/ noisy way.
# Unincluded factors = Random noise

# Bar Chart divide the values into intervals 
# Height is the mean of Y values of scatter points
# Relatioship can be found from the topmost middle interval point of every interval and then joining them
# Helps to calculate Global Trends
# For 2D data

# Histogram = Special case of bar charts
# For visualizing 1 Dimensional data 
# Usually frequency count on Y-axis

# Pie Chart (angle/360)*2*pi*r
# used in election outcomes

# %%
import matplotlib.pyplot as mp 
x = [3,4,2,4,3,5,3,6,4,3]
height = [1,2,4,6,5,4,6,4,5,1]
mp.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa360595c90>,
# ...
#  [Text(1.06451,0.277176,u''),
#   Text(0.726742,0.82574,u''),
#   Text(0.231747,1.07531,u''),
#   Text(-0.322105,1.05178,u''),
#   Text(-0.855839,0.691042,u''),
#   Text(-1.1,2.57474e-08,u''),
#   Text(-0.855839,-0.691042,u''),
#   Text(-0.13972,-1.09109,u''),
#   Text(0.726742,-0.82574,u''),
#   Text(1.06451,-0.277176,u'')])

# %%
mp.bar(x,height)
# Out:
# <BarContainer object of 10 artists>

# %%
mp.hist(x)
# Out:
# (array([ 1.,  0.,  4.,  0.,  0.,  3.,  0.,  1.,  0.,  1.]),
#  array([ 2. ,  2.4,  2.8,  3.2,  3.6,  4. ,  4.4,  4.8,  5.2,  5.6,  6. ]),
#  <a list of 10 Patch objects>)

# %%
mp.scatter(x,height)
